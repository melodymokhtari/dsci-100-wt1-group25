# %%
import pandas as pd
import altair as alt

# %% [markdown]
# The data consists of two seperate csv files, one called "players.csv" and one called "sessions.csv".
#
# There are 196 observations in the "players.csv" file, and it has a large list of variables. It has 9 columns of data, in which 2 are all null values. In the remaining 7, four have objects as values, one has floats, one has integers and one has boolean values.
#
# variables
# * experience (object), player's experience with MineCraft
# * subscribe (boolean), did they subscribe to their email service
# * hashedEmail (object), the hashed email of the player
# * played_hours (float), hours played in game
# * name (object), name of player
# * gender (object), gender of player
# * age (integer), age of player
#
#
# There are 1535 observations in the "sessions.csv" file, and it has 5 variables, in whcih 3 are objects and two are floats.
# * hashedEmail (object), the hashed email of the player
# * start_time, the time they started playing, given in
# * end_time, the time they ended playing
# * original_start_time
# * original_end_time

# %%
players = pd.read_csv("players.csv")
sessions=pd.read_csv("sessions.csv")
#players.info()
sessions.info()

sessions
#players_unique = players["individualId"].unique
#players_unique
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1535 entries, 0 to 1534
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   hashedEmail          1535 non-null   object
#  1   start_time           1535 non-null   object
#  2   end_time             1533 non-null   object
#  3   original_start_time  1535 non-null   float64
#  4   original_end_time    1533 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 60.1+ KB
#                                             hashedEmail        start_time  \
# 0     bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431...  30/06/2024 18:12
# 1     36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f5...  17/06/2024 23:33
# 2     f8f5477f5a2e53616ae37421b1c660b971192bd8ff77e3...  25/07/2024 17:34
# 3     bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431...  25/07/2024 03:22
# 4     36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f5...  25/05/2024 16:01
# ...
